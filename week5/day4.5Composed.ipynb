# %%
# !pip install langchain langchain-openai langchain-chroma chromadb openai numpy scikit-learn plotly
# Out:
# Requirement already satisfied: langchain in c:\users\paing\anaconda3\envs\llms\lib\site-packages (1.0.5)
# Requirement already satisfied: langchain-openai in c:\users\paing\anaconda3\envs\llms\lib\site-packages (1.0.2)
# Requirement already satisfied: langchain-chroma in c:\users\paing\anaconda3\envs\llms\lib\site-packages (1.0.0)
# Requirement already satisfied: chromadb in c:\users\paing\anaconda3\envs\llms\lib\site-packages (1.3.4)
# Requirement already satisfied: openai in c:\users\paing\anaconda3\envs\llms\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy in c:\users\paing\anaconda3\envs\llms\lib\site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\paing\anaconda3\envs\llms\lib\site-packages (1.7.2)
# Requirement already satisfied: plotly in c:\users\paing\anaconda3\envs\llms\lib\site-packages (6.4.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.4 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain) (1.0.4)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain) (1.0.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (0.4.41)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\paing\appdata\roaming\python\python311\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (23.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (8.5.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.4->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.2)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.11.0)
# Requirement already satisfied: certifi in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from openai) (0.11.0)
# Requirement already satisfied: sniffio in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.9.18)
# Requirement already satisfied: build>=1.0.3 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.38.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from chromadb) (0.19.2)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: six>=1.5 in c:\users\paing\appdata\roaming\python\python311\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\paing\appdata\roaming\python\python311\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.8.2)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (2.3.0)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from plotly) (2.10.2)
# Requirement already satisfied: pyproject_hooks in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\paing\appdata\roaming\python\python311\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.27.1)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.0)
# Requirement already satisfied: sympy in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.59b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\paing\appdata\roaming\python\python311\site-packages (from rich>=10.11.0->chromadb) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.35.3)
# Requirement already satisfied: filelock in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)

# %%
import os
import glob
from dotenv import load_dotenv
import gradio as gr
import sys 
sys.path.append("../../llm_engineering")
from api_clients import create_clients
from langchain_ollama import OllamaEmbeddings
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_chroma import Chroma
import numpy as np
from sklearn.manifold import TSNE
import plotly.graph_objects as go
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_community.vectorstores import FAISS

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp311-cp311-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in c:\users\paing\appdata\roaming\python\python311\site-packages (from faiss-cpu) (23.2)
# Downloading faiss_cpu-1.12.0-cp311-cp311-win_amd64.whl (18.2 MB)
#    ---------------------------------------- 0.0/18.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/18.2 MB ? eta -:--:--
#    - -------------------------------------- 0.8/18.2 MB 2.8 MB/s eta 0:00:07
#    -- ------------------------------------- 1.0/18.2 MB 2.2 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.8/18.2 MB 2.6 MB/s eta 0:00:07
#    ------ --------------------------------- 2.9/18.2 MB 3.3 MB/s eta 0:00:05
#    -------- ------------------------------- 3.9/18.2 MB 3.7 MB/s eta 0:00:04
#    ------------ --------------------------- 5.5/18.2 MB 4.1 MB/s eta 0:00:04
#    --------------- ------------------------ 6.8/18.2 MB 4.5 MB/s eta 0:00:03
#    ------------------ --------------------- 8.4/18.2 MB 4.8 MB/s eta 0:00:03
#    --------------------- ------------------ 9.7/18.2 MB 5.0 MB/s eta 0:00:02
#    ------------------------- -------------- 11.8/18.2 MB 5.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 13.4/18.2 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 15.7/18.2 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  17.8/18.2 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 18.2/18.2 MB 6.3 MB/s  0:00:03
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.12.0

# %%
# !pip install langchain-community
# Out:
# Requirement already satisfied: langchain-community in c:\users\paing\anaconda3\envs\llms\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-community) (1.0.4)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-community) (3.13.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-community) (2.11.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-community) (0.4.41)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\paing\appdata\roaming\python\python311\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (23.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.11.0)
# Requirement already satisfied: certifi in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.3.0)
# Requirement already satisfied: greenlet>=1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)

# %%
# !pip install langchain-huggingface
# Out:
# Requirement already satisfied: langchain-huggingface in c:\users\paing\anaconda3\envs\llms\lib\site-packages (1.0.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.33.4 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-huggingface) (0.35.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.3 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-huggingface) (1.0.4)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-huggingface) (0.22.1)
# Requirement already satisfied: filelock in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\paing\appdata\roaming\python\python311\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (6.0.3)
# Requirement already satisfied: requests in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (0.4.41)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (2.12.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (8.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (0.25.0)
# Requirement already satisfied: anyio in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (4.11.0)
# Requirement already satisfied: certifi in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (1.0.9)
# Requirement already satisfied: idna in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2.3.0)
# Requirement already satisfied: colorama in c:\users\paing\appdata\roaming\python\python311\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (1.3.1)

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\paing\anaconda3\envs\llms\lib\site-packages (5.1.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: tqdm in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from sentence-transformers) (2.9.0)
# Requirement already satisfied: scikit-learn in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from sentence-transformers) (0.35.3)
# Requirement already satisfied: Pillow in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\paing\appdata\roaming\python\python311\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.9.18)
# Requirement already satisfied: requests in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\paing\appdata\roaming\python\python311\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.10.5)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\paing\anaconda3\envs\llms\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)

# %%
from langchain_chroma import Chroma
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_huggingface import HuggingFaceEmbeddings

# %%
clients = create_clients()
db_name = "vector_db"

# %%
folders = glob.glob("knowledge-base/*")
text_loader_kwargs = {'encoding': 'utf-8'}
documents = []
for folder in folders:
    doc_type = os.path.basename(folder)
    loader = DirectoryLoader(folder, glob="**/*.md", loader_cls=TextLoader, loader_kwargs=text_loader_kwargs)
    folder_docs = loader.load()
    for doc in folder_docs:
        doc.metadata["doc_type"] = doc_type
        documents.append(doc)

# %%
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = text_splitter.split_documents(documents)
doc_types = set(chunk.metadata['doc_type'] for chunk in chunks)
# Out:
# Created a chunk of size 1088, which is longer than the specified 1000

# %%
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
if os.path.exists(db_name):
    Chroma(persist_directory=db_name, embedding_function=embeddings).delete_collection()

# %%
vectorstore = FAISS.from_documents(chunks, embedding=embeddings)

total_vectors = vectorstore.index.ntotal
dimensions = vectorstore.index.d

print(f"There are {total_vectors} vectors with {dimensions:,} dimensions in the vector store")
# Out:
# There are 123 vectors with 384 dimensions in the vector store

# %%
# Prework
vectors = []
documents = []
doc_types = []
colors = []
color_map = {'products':'blue', 'employees':'green', 'contracts':'red', 'company':'orange'}

for i in range(total_vectors):
    vectors.append(vectorstore.index.reconstruct(i))
    doc_id = vectorstore.index_to_docstore_id[i]
    document = vectorstore.docstore.search(doc_id)
    documents.append(document.page_content)
    doc_type = document.metadata['doc_type']
    doc_types.append(doc_type)
    colors.append(color_map[doc_type])
    
vectors = np.array(vectors)

# %%
tsne = TSNE(n_components=2, random_state=42)
reduced_vectors = tsne.fit_transform(vectors)

# Create the 2D scatter plot
fig = go.Figure(data=[go.Scatter(
    x=reduced_vectors[:, 0],
    y=reduced_vectors[:, 1],
    mode='markers',
    marker=dict(size=5, color=colors, opacity=0.8),
    text=[f"Type: {t}<br>Text: {d[:100]}..." for t, d in zip(doc_types, documents)],
    hoverinfo='text'
)])

fig.update_layout(
    title='2D FAISS Vector Store Visualization',
    scene=dict(xaxis_title='x',yaxis_title='y'),
    width=800,
    height=600,
    margin=dict(r=20, b=10, l=10, t=40)
)

fig.show()

# %%
# Let's try 3D!

tsne = TSNE(n_components=3, random_state=42)
reduced_vectors = tsne.fit_transform(vectors)

# Create the 3D scatter plot
fig = go.Figure(data=[go.Scatter3d(
    x=reduced_vectors[:, 0],
    y=reduced_vectors[:, 1],
    z=reduced_vectors[:, 2],
    mode='markers',
    marker=dict(size=5, color=colors, opacity=0.8),
    text=[f"Type: {t}<br>Text: {d[:100]}..." for t, d in zip(doc_types, documents)],
    hoverinfo='text'
)])

fig.update_layout(
    title='3D FAISS Vector Store Visualization',
    scene=dict(xaxis_title='x', yaxis_title='y', zaxis_title='z'),
    width=900,
    height=700,
    margin=dict(r=20, b=10, l=10, t=40)
)

fig.show()
